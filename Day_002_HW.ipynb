# %% [markdown]
# <a href="https://colab.research.google.com/github/hsingpei429/ML_marathon/blob/main/Day_002_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %%
   半導體科技業，因為這類產業擁有大量的製程資料，能夠滿足機器在學習數據之間的關聯性時需要的大量數據的前提。
   此外，對於半導體業追求極致良率的目標下，也相對擁有較少的不良資料、及繁雜的製程步驟，難以透過人工規則的建立找到不良品的原因，因此是非常適用機器學習的領域！
